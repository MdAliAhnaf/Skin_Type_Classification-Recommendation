# %%
import pandas as pd

EfficientNetB0 = pd.read_json('efficientnetb0_history.json') 
EfficientNetV2B0 = pd.read_json('efficientnetv2b0_history.json') 
MobileNetV2 = pd.read_json('mobilenetv2_history.json') 
MobileNetV3Small = pd.read_json('mobilenetv3small_history.json') 
ResNet50 = pd.read_json('resnet50_history.json') 
vgg16 = pd.read_json('vgg16_history.json')
print(vgg16.to_string())
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.123205  0.388090  3.666295      0.405797
# 1   1.069245  0.416838  3.834834      0.427536
# 2   1.010769  0.494867  3.730868      0.427536
# 3   0.995173  0.509240  3.737504      0.449275
# 4   0.945438  0.593429  3.507240      0.500000
# 5   0.902800  0.622177  3.454810      0.514493
# 6   0.870880  0.658203  3.537675      0.528986
# 7   0.838572  0.691992  3.574372      0.543478
# 8   0.827268  0.683594  3.826537      0.550725
# 9   0.798583  0.698152  3.877286      0.586957
# 10  0.771660  0.753906  3.873915      0.594203
# 11  0.737273  0.759754  3.875329      0.601449
# 12  0.708826  0.778234  4.096121      0.594203
# 13  0.692988  0.778234  4.130820      0.594203
# 14  0.675382  0.788501  4.173551      0.586957
# 15  0.641235  0.811088  4.343359      0.608696
# 16  0.615384  0.818359  4.449731      0.623188
# 17  0.629780  0.809035  4.537268      0.615942
# 18  0.564999  0.841889  4.531047      0.630435
# ...

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# List of model names
model_names = ['EfficientNetB0', 'EfficientNetV2B0', 'MobileNetV2', 'MobileNetV3Small', 'ResNet50',
               'vgg16']

N = epochs = 30

plt.style.use("ggplot")
sns.set_palette("husl")

plt.figure(figsize=(12, 8))

for model_name in model_names:
    model_data = pd.read_json(f'{model_name}_history.json')
    # plt.plot(np.arange(0, len(model_data)), model_data["loss"], label=f"{model_name}-train_loss")
    # plt.plot(np.arange(0, len(model_data)), model_data["val_loss"], label=f"{model_name}-val_loss")
    plt.plot(np.arange(0, len(model_data)), model_data["accuracy"], label=f"{model_name}-train_acc")
    # plt.plot(np.arange(0, len(model_data)), model_data["val_accuracy"], label=f"{model_name}-val_acc")

plt.title("Training Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Scale (0 - 1)")
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=True, ncol=4)

# Save figures in separate files
output_dir = 'plots'
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, 'train_accuracy.png'), bbox_inches='tight')
plt.show()
plt.close()

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# List of model names
model_names = ['EfficientNetB0', 'EfficientNetV2B0', 'MobileNetV2', 'MobileNetV3Small', 'ResNet50',
               'vgg16']

N = epochs = 30

plt.style.use("ggplot")
sns.set_palette("husl")

plt.figure(figsize=(12, 8))

for model_name in model_names:
    model_data = pd.read_json(f'{model_name}_history.json')
    plt.plot(np.arange(0, len(model_data)), model_data["loss"], label=f"{model_name}-train_loss")
    # plt.plot(np.arange(0, len(model_data)), model_data["val_loss"], label=f"{model_name}-val_loss")
    # plt.plot(np.arange(0, len(model_data)), model_data["accuracy"], label=f"{model_name}-train_acc")
    # plt.plot(np.arange(0, len(model_data)), model_data["val_accuracy"], label=f"{model_name}-val_acc")

plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Scale (0 - 1)")
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=True, ncol=4)

# Save figures in separate files
output_dir = 'plots'
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, 'train_loss.png'), bbox_inches='tight')
plt.show()
plt.close()

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# List of model names
model_names = ['EfficientNetB0', 'EfficientNetV2B0', 'MobileNetV2', 'MobileNetV3Small', 'ResNet50',
               'vgg16']
N = epochs = 30

plt.style.use("ggplot")
sns.set_palette("husl")

plt.figure(figsize=(12, 8))

for model_name in model_names:
    model_data = pd.read_json(f'{model_name}_history.json')
    # plt.plot(np.arange(0, len(model_data)), model_data["loss"], label=f"{model_name}-train_loss")
    # plt.plot(np.arange(0, len(model_data)), model_data["val_loss"], label=f"{model_name}-val_loss")
    # plt.plot(np.arange(0, len(model_data)), model_data["accuracy"], label=f"{model_name}-train_acc")
    plt.plot(np.arange(0, len(model_data)), model_data["val_accuracy"], label=f"{model_name}-val_acc")

plt.title("Validation Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Scale (0 - 1)")
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=True, ncol=4)

# Save figures in separate files
output_dir = 'plots'
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, 'Validation_accuracy.png'), bbox_inches='tight')
plt.show()
plt.close()

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# List of model names
model_names = ['EfficientNetB0', 'EfficientNetV2B0', 'MobileNetV2', 'MobileNetV3Small', 'ResNet50',
               'vgg16']

N = epochs = 30

plt.style.use("ggplot")
sns.set_palette("husl")

plt.figure(figsize=(12, 8))

for model_name in model_names:
    model_data = pd.read_json(f'{model_name}_history.json')
    # plt.plot(np.arange(0, len(model_data)), model_data["loss"], label=f"{model_name}-train_loss")
    plt.plot(np.arange(0, len(model_data)), model_data["val_loss"], label=f"{model_name}-val_loss")
    # plt.plot(np.arange(0, len(model_data)), model_data["accuracy"], label=f"{model_name}-train_acc")
    # plt.plot(np.arange(0, len(model_data)), model_data["val_accuracy"], label=f"{model_name}-val_acc")

plt.title("Validation Loss")
plt.xlabel("Epoch #")
plt.ylabel("Scale (0 - 1)")
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=True, ncol=4)

# Save figures in separate files
output_dir = 'plots'
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, 'Validation_loss.png'), bbox_inches='tight')
plt.show()
plt.close()
